# %%
# %pip install split-folders
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import splitfolders
splitfolders.ratio(input="dataset", output="split_data", seed=1337, ratio=(.70, .15, .15), group_prefix=None, move=False)
# Out:
# Copying files: 1888 files [00:11, 161.37 files/s]
